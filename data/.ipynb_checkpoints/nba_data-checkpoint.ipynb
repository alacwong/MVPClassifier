# %%
from bs4 import BeautifulSoup
from requests import get
import pandas as pd

# %%
### Each cell is to play with data so I can get familiar with the format. This way I can parse the data correctly
### when I add it to be database to then be trained

test = 'https://www.basketball-reference.com/leagues/NBA_2016_per_game.html'
response = get(test)
soup = BeautifulSoup(response.text, 'html.parser')

header_str = "Player	Pos	Age	Tm	G	GS	MP	FG	FGA	FG%	3P	3PA	3P%	2P	2PA	2P%\teFG%\tFT	FTA	FT%	ORB	DRB	TRB	" \
          "AST	STL	BLK	TOV	PF	PTS "

# table headers for each stat
headers = [header.strip() for header in header_str.split('\t')]

table = soup.find_all('td')
table_data = [t.text for t in table] # convert table matrix to list

num_rows = int(len(table_data)/len(headers))
row_length = len(headers)

players = []


def fun(x):
    try:
        return float(x)
    except ValueError:
        return x


for i in range(0, len(table_data), row_length):
    # row for player
    row = table_data[i: i+row_length]
    # convert to dict
    player = {headers[i]:fun(row[i]) for i in range(row_length)}
    players.append(player)
    

# # create new headers bc not all labels tell the correct story
# labels = headers[:]
# labels.remove('AGE')
# labels.remove('TM')


pt = pd.DataFrame(players)
test = pt[['Player', 'PTS']]
print(pt)




# find which columns need to be refactored to floats
for column in pt:
    print(column, pt[column].dtype)

print(len(table_data), num_rows, row_length)
print('There are ', len(players), ' in 2015/2016 nba season')
# Out:
#              Player Pos   Age   Tm     G    GS    MP   FG   FGA    FG%  ...  \
# 0        Quincy Acy  PF  25.0  SAC  59.0  29.0  14.8  2.0   3.6  0.556  ...
# 1      Jordan Adams  SG  21.0  MEM   2.0   0.0   7.5  1.0   3.0  0.333  ...
# 2      Steven Adams   C  22.0  OKC  80.0  80.0  25.2  3.3   5.3  0.613  ...
# 3     Arron Afflalo  SG  30.0  NYK  71.0  57.0  33.4  5.0  11.3  0.443  ...
# 4     Alexis Ajinça   C  27.0  NOP  59.0  17.0  14.6  2.5   5.3  0.476  ...
# ..              ...  ..   ...  ...   ...   ...   ...  ...   ...    ...  ...
# 573       Joe Young  PG  23.0  IND  41.0   0.0   9.4  1.5   4.1  0.367  ...
# 574      Nick Young  SG  30.0  LAL  54.0   2.0  19.1  2.3   6.9  0.339  ...
# 575  Thaddeus Young  PF  27.0  BRK  73.0  73.0  33.0  6.8  13.2  0.514  ...
# 576     Cody Zeller   C  23.0  CHO  73.0  60.0  24.3  3.2   6.0  0.529  ...
# 577    Tyler Zeller   C  26.0  BOS  60.0   3.0  11.8  2.3   4.8  0.476  ...
#
#        FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
### cell for scraping games won

# response = get('https://www.basketball-reference.com/leagues/NBA_1971_standings.html') 
response = get('https://www.basketball-reference.com/leagues/NBA_2001_standings.html') 

soup = BeautifulSoup(response.text, 'html.parser')

tables = soup.find_all('td')
l = [table for table in tables]


# filtering functions
def east_function(element):
    return [] != element.find_all('th', attrs={'aria-label':"Eastern Conference"})

def west_function(element):
    return [] != element.find_all('th', attrs={'aria-label':"Western Conference"})

# isolate for correct table
east = list(filter(east_function, l))[0] 
west = list(filter(west_function, l))[0]


# setup dictionary for team_link -> winrate for season
wr = list(east.find_all('td', attrs={"data-stat":'win_loss_pct'})) + list(west.find_all('td', attrs={"data-stat":'win_loss_pct'}))
teams = list(east.find_all('a')) + list(west.find_all('a'))
nba = {teams[i]['href']: float(wr[i].text) for i in range(len(wr))}
print(nba)
# Out:
# {'/teams/PHI/2001.html': 0.683, '/teams/MIA/2001.html': 0.61, '/teams/NYK/2001.html': 0.585, '/teams/ORL/2001.html': 0.524, '/teams/BOS/2001.html': 0.439, '/teams/NJN/2001.html': 0.317, '/teams/WAS/2001.html': 0.232, '/teams/MIL/2001.html': 0.634, '/teams/TOR/2001.html': 0.573, '/teams/CHH/2001.html': 0.561, '/teams/IND/2001.html': 0.5, '/teams/DET/2001.html': 0.39, '/teams/CLE/2001.html': 0.366, '/teams/ATL/2001.html': 0.305, '/teams/CHI/2001.html': 0.183, '/teams/SAS/2001.html': 0.707, '/teams/UTA/2001.html': 0.646, '/teams/DAL/2001.html': 0.646, '/teams/MIN/2001.html': 0.573, '/teams/HOU/2001.html': 0.549, '/teams/DEN/2001.html': 0.488, '/teams/VAN/2001.html': 0.28, '/teams/LAL/2001.html': 0.683, '/teams/SAC/2001.html': 0.671, '/teams/PHO/2001.html': 0.622, '/teams/POR/2001.html': 0.61, '/teams/SEA/2001.html': 0.537, '/teams/LAC/2001.html': 0.378, '/teams/GSW/2001.html': 0.207}

# %%
# scrape data for mvp candidates
url = 'https://www.basketball-reference.com/awards/awards_2001.html'
response = get(url)
soup = BeautifulSoup(response.text, 'html.parser')
tables = soup.find_all('table')
l = [table for table in tables]

headers = l[0].find_all('th', attrs={'scope': 'col'})
headers = [h.text for h in headers] # scrape column headers for mvp candidates
headers.remove('Rank')
stats = l[0].find_all('td') # data for mvp candidates

# setup links to teams
team_link = {}
for stat in stats:
    link = stat.find_all('a')
    if link != [] and len(stat.text) == 3:
        team_link[stat.text] = nba[link[0]['href']]
        
stats = [s.text for s in stats] 
mvps = []

for i in range(0, len(stats), len(headers)):
    row = stats[i: i+len(headers)]
    mvp = {headers[j]:row[j] for j in range(len(row))}
    mvps.append(mvp)
df = pd.DataFrame(mvps) # raw table
df['Tm'] = df['Tm'] = df['Tm'].apply(lambda x: team_link[x]) # get winrate
# delete irrelevant fields
del df['G']
del df['Pts Won']
del df['Pts Max']
del df['First']
del df['Age']
print(df)

# we want a subset of the raw data before training the model
# we want to look at important
# Out:
#               Player     Tm  Share    MP   PTS   TRB  AST  STL  BLK   FG%  \
# 0      Allen Iverson  0.683  0.904  42.0  31.1   3.8  4.6  2.5  0.3  .420
# 1         Tim Duncan  0.707  0.569  38.7  22.2  12.2  3.0  0.9  2.3  .499
# 2   Shaquille O'Neal  0.683  0.466  39.5  28.7  12.7  3.7  0.6  2.8  .572
# 3       Chris Webber  0.671  0.420  40.5  27.1  11.1  4.2  1.3  1.7  .481
# 4      Kevin Garnett  0.573  0.122  39.5  22.0  11.4  5.0  1.4  1.8  .477
# 5      Tracy McGrady  0.524  0.052  40.1  26.8   7.5  4.6  1.5  1.5  .457
# 6        Karl Malone  0.646  0.017  35.7  23.2   8.3  4.5  1.1  0.8  .498
# 7         Jason Kidd  0.622  0.015  39.8  16.9   6.4  9.8  2.2  0.3  .411
# 8        Kobe Bryant  0.683  0.009  40.9  28.5   5.9  5.0  1.7  0.6  .464
# 9     David Robinson  0.707  0.006  29.6  14.4   8.6  1.5  1.0  2.5  .486
# 10         Ray Allen  0.634  0.006  38.2  22.0   5.2  4.6  1.5  0.2  .480
# 11      Vince Carter  0.573  0.006  39.7  27.6   5.5  3.9  1.5  1.1  .460
# ...

# %%
# cell of cleaing df
print(df)
df2 = df.copy()

# get rid empty cells and
for col in df2:
    count = 0
    for i in range(len(df2[col])):
        if df2[col][i] == '':
            df2.loc[i, col] = '0'
            count+=1
    if count == len(df2[col]):
        del df2[col]

# setup correct types for table
for col in df2:
    df2[col] = pd.to_numeric(df2[col], errors='ignore')

print(df2)
# Out:
#               Player     Tm  Share    MP   PTS   TRB  AST  STL  BLK   FG%  \
# 0      Allen Iverson  0.683  0.904  42.0  31.1   3.8  4.6  2.5  0.3  .420
# 1         Tim Duncan  0.707  0.569  38.7  22.2  12.2  3.0  0.9  2.3  .499
# 2   Shaquille O'Neal  0.683  0.466  39.5  28.7  12.7  3.7  0.6  2.8  .572
# 3       Chris Webber  0.671  0.420  40.5  27.1  11.1  4.2  1.3  1.7  .481
# 4      Kevin Garnett  0.573  0.122  39.5  22.0  11.4  5.0  1.4  1.8  .477
# 5      Tracy McGrady  0.524  0.052  40.1  26.8   7.5  4.6  1.5  1.5  .457
# 6        Karl Malone  0.646  0.017  35.7  23.2   8.3  4.5  1.1  0.8  .498
# 7         Jason Kidd  0.622  0.015  39.8  16.9   6.4  9.8  2.2  0.3  .411
# 8        Kobe Bryant  0.683  0.009  40.9  28.5   5.9  5.0  1.7  0.6  .464
# 9     David Robinson  0.707  0.006  29.6  14.4   8.6  1.5  1.0  2.5  .486
# 10         Ray Allen  0.634  0.006  38.2  22.0   5.2  4.6  1.5  0.2  .480
# 11      Vince Carter  0.573  0.006  39.7  27.6   5.5  3.9  1.5  1.1  .460
# ...
